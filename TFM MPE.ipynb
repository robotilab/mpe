# %% [markdown]
# <div  style="float:left; width:100%;">
# <h2  style="text-align:center;">TRABAJO FIN DE MASTER</h2>
# <p style="font-weight:bold; font-size:2em;text-align: center;color:purple">Aplicación de Jupyter Notebook en Educación</p>
# <p style="text-align:right;">Tutora: <strong>María Isabel Doval Ruiz</strong></p>
# <p style="text-align:right;">Alumno: <strong>Alberto Álvarez Vales</strong></p>
# </div>

# %% [markdown]
# <h2>¿Qué es un "notebook"?</h2>
# <p><img style="display:block;margin:auto;width:80%;border-radius: 8px;" src="data:image/png;base64,..." alt="image.png"></p>

# %% [markdown]
# <h2 style="margin-left:0cm;text-indent:0cm">Ecosistema Jupyter</h2>
#
# <br>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Kernel</b> (45 lenguajes)</p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Jupyter Lab</b> (interfaz de usuario avanzada)</p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Widgets</b> (controles: botones, desplegables, etc)</p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Extensiones</b> (RISE, nbgrader, etc)</p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Jupyter Hub</b> (Servidor)</p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Soluciones "Cloud" gratuitas:</b>
#     <ul style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify">
#         <li>Colaboratory de Google</li>
#         <li>Microsoft Azure Notebook</li>
#         <li>Kaggle</li>
#         <li>Datalore</li>
#         <li>Binder</li>
#     </ul>
#         </p>

# %% [markdown]
# <h2 style="margin-left:0cm;text-indent:0cm">Posibilidades
# pedagógicas más utilizadas</h2>
#
# <br>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Libros de texto</b></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Aplicaciones</b></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Actividades </b></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Presentaciones y demostraciones </b></p>

# %% [markdown]
# <h2 style="margin-left:0cm;text-indent:0cm">Casos analizados</h2>
#
# <br>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Jupyter Notebooks used for 7th Grade Technology Unit on Python </b><i>(Moore, 2019)</i></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>CODINGinK12. Notebooks para Primaria y Secundaria en USA </b><i>(Lamee, 2019)</i></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Jupyter notebooks for physical chemistry education. Universidad </b><i>(Rowell, 2018)</i></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Cal Poly SLO’s EPIC. Taller introductorio informática </b><i>(Barba et al., 2019)</i></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Introducción a Python </b><i>(Villegas, 2019)</i></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b>Cursos de Big Data. Programación y análisis de datos para titulados </b><i>(Experiencia personal)</i></p>

# %% [markdown]
# <h2 style="margin-left:0cm;text-indent:0cm">Resumen</h2>
#
# <br>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify">El uso más habitual es el de <b>libro de texto </b> <i>mejorado</i></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify">En la mayoría de los casos el alumno debe cubrir <b>actividades en los notebook</b><i></i></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify">En <b>CODINGinK12</b> se utiliza de forma tranversal para otras asignaturas: geografía, matemáticas, física y química<i></i></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"> En los notebooks de Química para la universidad se utiliza HTML y LATEX, además de gráficas de todos los procesos<b></b><i></i></p>

# %% [markdown]
# <h2 style="margin-left:0cm;text-indent:0cm">Propuesta para 1º de bachillerato</h2>
#
# <br>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify">En la mayoría de los  <b></b><i></i></p>

# %% [markdown]
# ### _Ejemplo de uso en 1º de bachillerato:_
# # Bucle _for_
# El bucle _for_ es una estructura de control en programación en la que se puede indicar de antemano el número mínimo de iteraciones.

# %%
for i in (1,2,3):
    print("n= ",i)
# Out:
# n=  1
# n=  2
# n=  3

# %% [markdown]
# Escribe un bloque de código para que se muestren por pantalla los números pares de 0 a 10.

# %%
#escribe aquí...

# %%
import matematicas1bac # Ejemplo de aplicación con widgets
display(matematicas1bac.aplic)

# %%
#Ejemplo de seudocódigo
import convierte, math
convierte.grados_a_radianes(180)
# Out:
# <img style='width:300px' src=data:image/png;base64,...><span style='color:purple'><b>¡Recuerda!</b> La conversión de grados a radianes se realiza con la siguiente fórmula:</span><BR><H3>$radianes=\frac{grados*\pi}{180}$</H3>
# 3.141592653589793

# %% [markdown]
# <h2 style="margin-left:0cm;text-indent:0cm">Reflexiones finales</h2>
#
# <br>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify">Jupyter Notebook es <b>código abierto</b></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify">Los <b>notebook</b> están en un formato(JSON) que permite incorporar información adicional</p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"> En Educación <b>no se están aprovechando todas las posibilidades</b></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify">La <b>comunidad en crecimiento</b></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify">Empresas como Google, Microsoft o Amazon <b>utilizan notebooks en entorno profesional</b></p>
#
# <p class="MsoNormal" style="margin-top:0cm;margin-right:0cm;margin-bottom:12.0pt;
# margin-left:35.4pt;text-align:justify"><b></b></p>

# %% [markdown]
# <h1 style="display:block;margin:auto;width:80%;border-radius: 8px;text-align:center;"> ¡Gracias por su atención!</h1>
